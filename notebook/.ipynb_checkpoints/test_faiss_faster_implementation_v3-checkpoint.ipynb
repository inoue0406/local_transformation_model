# %% [markdown]
# # test for interpolation routine with feiss GPU

# %%
from torch import nn
import torch.nn.functional as F
import torch
import os
import sys
import matplotlib.pyplot as plt
import importlib

# %%
import faiss

# %%
# -----------------------------
# add "src" as import path
path = os.path.join('/home/tsuyoshi/local_transformation_model/src/')
sys.path.append(path)

# %%
import numpy as np
#from src_rev_bilinear.rev_bilinear_interp import RevBilinear
from nearest_neighbor_interp import nearest_neighbor_interp_fe

# %%
nearest_neighbor_interp_fe
# Out:
# <function nearest_neighbor_interp.nearest_neighbor_interp_fe(xy_A_b, xy_B_b, R_B_b)>

# %%
# plot a 2-d field
def plot_field(X,title,vmin=0,vmax=1):
    plt.imshow(X,vmin=vmin,vmax=vmax,cmap="GnBu",origin='lower')
    plt.colorbar()
    plt.grid()
    plt.title(title)
    plt.show()

# %%
def grid_to_pc_nearest(R_grd,XY_pc,XY_grd,index):
    # convert grid to pc
    # R_grd: grid value with [batch,channels,height,width] dim
    # XY_pc: point cloud position with [batch,2,N] dim
    #        scaled to [0,1]
    batch,k,height,width = R_grd.shape
    XY_grd_tmp = XY_grd.reshape(batch,2,height*width).permute(0,2,1).detach()
    XY_pc_tmp = XY_pc.permute(0,2,1).detach()
    R_grd_tmp = R_grd.reshape(batch,k,height*width)
    #R_pc = nearest_neighbor_interp(XY_pc_tmp,XY_grd_tmp,R_grd_tmp)
    #R_pc = nearest_neighbor_interp_kd(XY_pc_tmp,XY_grd_tmp,R_grd_tmp)
    R_pc = nearest_neighbor_interp_fi(XY_pc_tmp,XY_grd_tmp,R_grd_tmp,index,"forward")
    #import pdb;pdb.set_trace()
    return R_pc

# %%
def pc_to_grid_nearest(R_pc,XY_pc,XY_grd,index):
    # convert pc to grid
    # R_pc: point cloud value with [batch,channels,N] dim
    # XY_pc: point cloud position with [batch,2,N] dim
    #        scaled to [0,1]
    batch,_,height,width = XY_grd.shape
    _,k,_ = R_pc.shape
    XY_grd_tmp = XY_grd.reshape(batch,2,height*width).permute(0,2,1).detach()
    XY_pc_tmp = XY_pc.permute(0,2,1).detach()
    #R_grd = nearest_neighbor_interp(XY_grd_tmp,XY_pc_tmp,R_pc)
    #R_grd = nearest_neighbor_interp_kd(XY_grd_tmp,XY_pc_tmp,R_pc)
    #R_grd = nearest_neighbor_interp_kd(XY_pc_tmp,XY_grd_tmp,R_pc)
    R_grd = nearest_neighbor_interp_fi(XY_grd_tmp,XY_pc_tmp,R_pc,index,"backward")
    #import pdb;pdb.set_trace()
    R_grd = R_grd.reshape(batch,k,height,width)
    return R_grd

# %%
def set_index_faiss(points_B):
    # set FAISS index
    # points_B : numpy array with Mx2 dimension
    #method = "FlatIP"
    method = "IVF"
    if method == "FlatIP":
        res = faiss.StandardGpuResources()
        index = faiss.GpuIndexFlatIP(res, 2)
        index.add(points_B)
    elif method == "IVF":
        res = faiss.StandardGpuResources()
        nlist = 100
        quantizer = faiss.IndexFlatL2(2)  # the other index
        index_ivf = faiss.IndexIVFFlat(quantizer, 2, nlist, faiss.METRIC_L2)
        # here we specify METRIC_L2, by default it performs inner-product search
        # make it an IVF GPU index
        index = faiss.index_cpu_to_gpu(res, 0, index_ivf)

        assert not index.is_trained
        index.train(points_B)        # add vectors to the index
        assert index.is_trained
        index.add(points_B)          # add vectors to the index
    return index

# %% [markdown]
# ## Dims

# %%
bsize = 10
tsize = 12
channels = 1
# Grid Size
#height = 10
#width = 10
height = 200
width = 200
# Particle Size
#npc = 40000
npc = 30000

# %%
def xy_grid(height,width):
    # generate constant xy grid
    x1grd = torch.linspace(0,1,width).cuda() # 1d grid
    y1grd = torch.linspace(0,1,height).cuda() # 1d grid

    Xgrid = torch.zeros(height, width)
    Ygrid = torch.zeros(height, width)
    for j in range(height):
        Xgrid[j,:] = x1grd
    for k in range(width):
        Ygrid[:,k] = y1grd
    return Xgrid,Ygrid

# %% [markdown]
# ## Prepare Grids

# %%
Xgrid,Ygrid = xy_grid(height,width)

# %%
# Set Initial Grid (which will be fixed through time progress)
X_grd = torch.stack(bsize*[Xgrid]).unsqueeze(1)
Y_grd = torch.stack(bsize*[Ygrid]).unsqueeze(1)
XY_grd = torch.cat([X_grd,Y_grd],dim=1).cuda()
# Set Initial PC
#XY_pc = torch.zeros(bsize,2,npc).cuda()
XY_pc = torch.rand(bsize,2,npc).cuda() #[0-1]

# %%
torch.max(XY_pc)
# Out:
# tensor(1.0000, device='cuda:0')

# %%
XY_pc.shape
# Out:
# torch.Size([10, 2, 30000])

# %%
XY_grd.shape
# Out:
# torch.Size([10, 2, 200, 200])

# %%
# Set initial rain field

# %%
ic=0.5
jc=0.5
scale=0.1
R_grd = torch.exp(-((X_grd-ic)**2 + (Y_grd-jc)**2)/scale**2)
R_grd = R_grd.cuda()

# %%
R_grd.shape
# Out:
# torch.Size([10, 1, 200, 200])

# %%
# test plot for initial grid
rtmp = R_grd[0,0,:,:].detach().cpu().numpy()
plot_field(rtmp,"initial field")

# %%
#set UV
UV_grd = torch.zeros(bsize,tsize, 2,height, width).cuda()
UV_grd = UV_grd + 0.03

# %%
# prepare regular grid for index
points_grd = XY_grd[0,:,:].reshape(2,height*width).permute(1,0).detach().cpu().numpy()

# %%
points_grd.shape
# Out:
# (40000, 2)

# %%
# set FAISS index
index = set_index_faiss(points_grd)

# %%
index
# Out:
# <faiss.swigfaiss_avx2.GpuIndexIVFFlat; proxy of <Swig Object of type 'faiss::gpu::GpuIndexIVFFlat *' at 0x7fe4d02f6990> >

# %%
import nearest_neighbor_interp 
importlib.reload(nearest_neighbor_interp)
from nearest_neighbor_interp import nearest_neighbor_interp_fi
# initialize R_pc
R_pc = grid_to_pc_nearest(R_grd[:,:,:,:],XY_pc,XY_grd,index)
# initialize 
R_grd_all = torch.zeros(bsize,tsize, 1,height, width).cuda()
# Out:
# R_B_b shape torch.Size([10, 1, 40000])
# id_min shape torch.Size([10, 1, 30000])

# %%
#torch.max(R_pc)

# %%
# %%time
#it = 0
# loop through time dim
for it in range(tsize):
    print("it=",it)
    # convert R and UV to point cloud
    UV_pc = grid_to_pc_nearest(UV_grd[:,it,:,:,:],XY_pc,XY_grd,index)
    # time progress
    XY_pc = XY_pc + UV_pc
    # go back to grid
    R_grd_all[:,it,:,:,:] = pc_to_grid_nearest(R_pc,XY_pc,XY_grd,index)
# Out:
# it= 0
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 1
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 2
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 3
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 4
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 5
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 6
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 7
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 8
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 9
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 10
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# it= 11
# R_B_b shape torch.Size([10, 2, 40000])
# id_min shape torch.Size([10, 2, 30000])
# R_B_b shape torch.Size([10, 1, 30000])
# id_min shape torch.Size([10, 1, 40000])
# CPU times: user 31.5 s, sys: 658 ms, total: 32.1 s
# Wall time: 2.7 s

# %%
# test plot for time progress
for it in range(5):
    #it = 1
    rtmp = R_grd_all[0,it,0,:,:].detach().cpu().numpy()
    plot_field(rtmp,"it=%d" % it)

# %%
torch.max(XY_pc)
torch.max(XY_grd)
#torch.max(R_grd_all)
# Out:
# tensor(1., device='cuda:0')

# %%
# Animation
#figオブジェクトを作る
fig = plt.figure()
#空のリストを作る
ims = []
#10個の画像を繋げたアニメーションにする
for it in range(tsize):
    #1枚1枚のグラフを描き、appendしていく
    title="it=%d" % i
    #X = #R_grd_all[0,it,0,:,:].detach().cpu().numpy()
    X = R_grd[0,0,:,:].detach().cpu().numpy()
    im = plt.imshow(X,vmin=0,vmax=1,cmap="GnBu",origin='lower')
    #plt.colorbar()
    #plt.grid()
    #plt.title(title)
    ims.append(im)     
#アニメーション作成 
ani = animation.ArtistAnimation(fig, ims, interval=200, repeat_delay=1000)
plt.show()
